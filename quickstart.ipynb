# %% [markdown]
# Copyright (c) Meta Platforms, Inc. and affiliates.
# This software may be used and distributed according to the terms of the Llama 2 Community License Agreement.

# %% [markdown]
# ## Quick Start Notebook
#
# This notebook shows how to train a Llama 2 model on a single GPU (e.g. A10 with 24GB) using int8 quantization and LoRA.
#
# ### Step 0: Install pre-requirements and convert checkpoint
#
# The example uses the Hugging Face trainer and model which means that the checkpoint has to be converted from its original format into the dedicated Hugging Face format.
# The conversion can be achieved by running the `convert_llama_weights_to_hf.py` script provided with the transformer package.
# Given that the original checkpoint resides under `models/7B` we can install all requirements and convert the checkpoint with:

# %%
# %%bash
# pip install transformers datasets accelerate sentencepiece protobuf==3.20 py7zr scipy peft bitsandbytes fire torch_tb_profiler ipywidgets
# TRANSFORM=`python -c "import transformers;print('/'.join(transformers.__file__.split('/')[:-1])+'/models/llama/convert_llama_weights_to_hf.py')"`
# python ${TRANSFORM} --input_dir models --model_size 7B --output_dir models_hf/7B

# %% [markdown]
# ### Step 1: Load the model
#
# Point model_id to model weight folder

# %%
import torch
from transformers import LlamaForCausalLM, LlamaTokenizer

model_id="../llama/hugging_face_weights/base/7B"

tokenizer = LlamaTokenizer.from_pretrained(model_id)

model =LlamaForCausalLM.from_pretrained(model_id, load_in_8bit=True, device_map='auto', torch_dtype=torch.float16)
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.8/dist-packages/bitsandbytes/libbitsandbytes_cuda113.so
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching in backup paths...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so.11.0
# CUDA SETUP: Highest compute capability among GPUs detected: 8.6
# CUDA SETUP: Detected CUDA version 113
# CUDA SETUP: Loading binary /usr/local/lib/python3.8/dist-packages/bitsandbytes/libbitsandbytes_cuda113.so...
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('Asia/Tokyo')}
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//matplotlib_inline.backend_inline')}
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: Found duplicate ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] files: {PosixPath('/usr/local/cuda/lib64/libcudart.so.11.0'), PosixPath('/usr/local/cuda/lib64/libcudart.so')}.. We'll flip a coin and try one of these, in order to fail forward.
# Either way, this might cause trouble in the future:
# If you get `CUDA error: invalid device function` errors, the above might be the cause and the solution is to make sure only one ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] in the paths that we search based on your env.
#   warn(msg)
# You are using the legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This means that tokens that come after special tokens will not be properly handled. We recommend you to read the related pull request available at https://github.com/huggingface/transformers/pull/24565
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Step 2: Load the preprocessed dataset
#
# We load and preprocess the samsum dataset which consists of curated pairs of dialogs and their summarization:

# %%
from pathlib import Path
import os
import sys
from utils.dataset_utils import get_preprocessed_dataset
from configs.datasets import samsum_dataset, receipt_dataset

train_dataset = get_preprocessed_dataset(tokenizer, receipt_dataset, 'train')
# Out:
# running on partition train; there are 71 samples

# %%
len(train_dataset)
# Out:
# 71

# %% [markdown]
# ### Step 3: Check base model
#
# Run the base model on an example input:

# %%
eval_prompt = """
以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。
### 項目一覧
[請求時分],[消費税額(8%)],[消費税額(10%)],[ページ番号],[支払者名],[請求者FAX],[支払通貨],[請求年月],[合計請求額(税抜)],[口座名義],[口座番号],[口座の種類],[銀行支店名],[銀行名],[支払期日],[消費税額],[合計請求額(税込)],[支払者会社名],[請求者電話番号],[請求者住所],[請求者会社名],[タイトル],[請求番号],[請求日付],[請求額(8%税込)],[請求額(10%税込)],[登録番号]
### テキスト一覧
2023年 6月23日\t令和3年8月分\t前田道路株式会社 御中
下記の通り請求致します
請 求\t書\t(材料その他用)
(業 者 控)
適格請求書株式会社
住\t所
名
発行者登録番号\tT1231231231235
※支払期限\t2022/7/31
みずほ\t銀行 東京\t支店\t普通\t当座\t1234567
⑪
(取引先コード欄)
金額
¥70,200
月日\t品\t名\t納入場所\t工事 №.\t数量\t単位\t単価\t金\t額\t担当
6/23\t*品名1\t三田倉庫\t001\t1.0\t個\t65,000\t65,000
小\t計\t¥65,000
10%
消費税計\t消費税率\t8%\t¥5,200
請求\t金\t額\t¥70,200
(注)1.毎月末日締切で、翌月2日迄に必着するよう提出して下さい。
2.提出用のシートを2枚印刷して、提出してください。
3.取引先コード欄に貴社コードのゴム印を押印または、貴社コードを入力してください。

### Json Output:
"""

model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")

model.eval()
with torch.no_grad():
    print(tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True))
# Out:
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。
# ### 項目一覧
# [請求時分],[消費税額(8%)],[消費税額(10%)],[ページ番号],[支払者名],[請求者FAX],[支払通貨],[請求年月],[合計請求額(税抜)],[口座名義],[口座番号],[口座の種類],[銀行支店名],[銀行名],[支払期日],[消費税額],[合計請求額(税込)],[支払者会社名],[請求者電話番号],[請求者住所],[請求者会社名],[タイトル],[請求番号],[請求日付],[請求額(8%税込)],[請求額(10%税込)],[登録番号]
# ### テキスト一覧
# 2023年 6月23日	令和3年8月分	前田道路株式会社 御中
# 下記の通り請求致します
# 請 求	書	(材料その他用)
# (業 者 控)
# 適格請求書株式会社
# 住	所
# 名
# 発行者登録番号	T1231231231235
# ※支払期限	2022/7/31
# みずほ	銀行 東京	支店	普通	当座	1234567
# ⑪
# (取引先コード欄)
# 金額
# ¥70,200
# 月日	品	名	納入場所	工事 №.	数量	単位	単価	金	額	担当
# 6/23	*品名1	三田倉庫	001	1.0	個	65,000	65,000
# 小	計	¥65,000
# 10%
# 消費税計	消費税率	8%	¥5,200
# 請求	金	額	¥70,200
# (注)1.毎月末日締切で、翌月2日迄に必着するよう提出して下さい。
# 2.提出用のシートを2枚印刷して、提出してください。
# 3.取引先コード欄に貴社コードのゴム印を押印または、貴社コードを入力してください。
#
# ### Json Output:
# [
#   {
#     "請求時分": "2023年 6月23日",
#     "消費税額(8%)": "5200",
#     "消費税額(10%)": "5200",
#     "ページ番号": "1",
#     "支払者名": "前田道路株式会社",
#     "請求者FAX": "03-3333-3333",
#     "支払通貨": "日本円",
#     "請求年月": "2023年 6月",
#     "合計請求額(税抜)": "70200",
#     "口座名義": "前田道路株式会社",
#     "口座番号": "1234567",
#     "口座の種類": "普通",
#     "銀行支店名": "みずほ銀行 東京支店",
#     "銀行名": "みずほ銀行",
#     "支払期日": "2022/7/31",
#     "消費税額": "5200",
#     "合計請求額(税込)": "70200",
#     "支払者会社名": "前田道路株式会社",
#     "請求者電話番号": "03-3333-3333",
#     "請求者住所": "東京都千代田区三田",
#     "請求者会社名": "前田道路株式会社",
#     "タイトル": "請求書",
#     "請求番号": "...

# %% [markdown]
# We can see that the base model only repeats the conversation.
#
# ### Step 4: Prepare model for PEFT
#
# Let's prepare the model for Parameter Efficient Fine Tuning (PEFT):

# %%
model.train()

def create_peft_config(model):
    from peft import (
        get_peft_model,
        LoraConfig,
        TaskType,
        prepare_model_for_int8_training,
    )

    peft_config = LoraConfig(
        task_type=TaskType.CAUSAL_LM,
        inference_mode=False,
        r=8,
        lora_alpha=32,
        lora_dropout=0.05,
        target_modules = ["q_proj", "v_proj"]
    )

    # prepare int-8 model for training
    model = prepare_model_for_int8_training(model)
    model = get_peft_model(model, peft_config)
    model.print_trainable_parameters()
    return model, peft_config

# create peft config
model, lora_config = create_peft_config(model)
# Out:
# /usr/local/lib/python3.8/dist-packages/peft/utils/other.py:119: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# trainable params: 4,194,304 || all params: 6,742,609,920 || trainable%: 0.06220594176090199

# %%
model.train()

def create_peft_config(model):
    from peft import (
        get_peft_model,
        LoraConfig,
        TaskType,
        prepare_model_for_int8_training,
    )

    peft_config = LoraConfig(
        task_type=TaskType.CAUSAL_LM,
        inference_mode=False,
        r=8,
        lora_alpha=32,
        lora_dropout=0.05,
        target_modules = ["q_proj", "v_proj"]
    )

    # prepare int-8 model for training
    model = prepare_model_for_int8_training(model)
    model = get_peft_model(model, peft_config)
    model.print_trainable_parameters()
    return model, peft_config

# create peft config
model, lora_config = create_peft_config(model)
# Out:
# /usr/local/lib/python3.8/dist-packages/peft/utils/other.py:119: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# trainable params: 4,194,304 || all params: 6,742,609,920 || trainable%: 0.06220594176090199

# %%
from peft import (
        get_peft_model,
        LoraConfig,
        TaskType,
        prepare_model_for_int8_training,
    )

peft_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM,
    inference_mode=False,
    r=8,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules = ["q_proj", "v_proj"]
)

# prepare int-8 model for training
model = prepare_model_for_int8_training(model)
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# %% [markdown]
# ### Step 5: Define an optional profiler

# %%
from transformers import TrainerCallback
from contextlib import nullcontext
enable_profiler = False
output_dir = "tmp/llama-output-7b-r-8-useless"

config = {
    'lora_config': lora_config,
    'learning_rate': 1e-4,
    'num_train_epochs': 1,
    'gradient_accumulation_steps': 2,
    'per_device_train_batch_size': 4,
    'gradient_checkpointing': False,
}

# Set up profiler
if enable_profiler:
    wait, warmup, active, repeat = 1, 1, 2, 1
    total_steps = (wait + warmup + active) * (1 + repeat)
    schedule =  torch.profiler.schedule(wait=wait, warmup=warmup, active=active, repeat=repeat)
    profiler = torch.profiler.profile(
        schedule=schedule,
        on_trace_ready=torch.profiler.tensorboard_trace_handler(f"{output_dir}/logs/tensorboard"),
        record_shapes=True,
        profile_memory=True,
        with_stack=True)
    
    class ProfilerCallback(TrainerCallback):
        def __init__(self, profiler):
            self.profiler = profiler
            
        def on_step_end(self, *args, **kwargs):
            self.profiler.step()

    profiler_callback = ProfilerCallback(profiler)
else:
    profiler = nullcontext()

# %% [markdown]
# ### Step 6: Fine tune the model
#
# Here, we fine tune the model for a single epoch which takes a bit more than an hour on a A100.

# %%
from transformers import default_data_collator, Trainer, TrainingArguments



# Define training args
training_args = TrainingArguments(
    output_dir=output_dir,
    overwrite_output_dir=True,
    bf16=True,  # Use BF16 if available
    # logging strategies
    logging_dir=f"{output_dir}/logs",
    logging_strategy="steps",
    logging_steps=10,
    save_strategy="no",
    optim="adamw_torch_fused",
    max_steps=total_steps if enable_profiler else -1,
    **{k:v for k,v in config.items() if k != 'lora_config'}
)

with profiler:
    # Create Trainer instance
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        data_collator=default_data_collator,
        callbacks=[profiler_callback] if enable_profiler else [],
    )

    # Star t training
    trainer.train()
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/autograd/_functions.py:321: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/autograd/_functions.py:321: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 05:02, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %% [markdown]
# ### Step 7:
# Save model checkpoint

# %%
model.save_pretrained(output_dir)

# %% [markdown]
# ## Load Dual Model

# %%
import torch
from peft import PeftModel    
from transformers import AutoModelForCausalLM, AutoTokenizer, LlamaTokenizer, StoppingCriteria, StoppingCriteriaList, TextIteratorStreamer

import time
model_name = "../llama/hugging_face_weights/base/7B"
adapters_name_1 = "tmp/llama-output-7b-r-8"
adapters_name_2 = "tmp/llama-output-7b-r-8-useless"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    # load_in_4bit=True,
    torch_dtype=torch.bfloat16,
    device_map={"": 0}
)
model = PeftModel.from_pretrained(model, adapters_name_1, adapter_name="main")
model.load_adapter(adapters_name_2, adapter_name="sub")

# model = model.merge_and_unload()
tokenizer = LlamaTokenizer.from_pretrained(model_name)
tokenizer.bos_token_id = 1

stop_token_ids = [0]

model.eval()
with torch.no_grad():
    start_time = time.time()
    for _ in range(5):
        tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True)
    end_time = time.time()
    print(f"Inference time: {end_time - start_time} seconds")

# Merging and unloading

start = time.time()
model.set_adapter("sub")
print("Change Adapter: ", time.time() - start)
model.eval()
with torch.no_grad():
    start_time = time.time()
    for _ in range(5):
        tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True)
    end_time = time.time()
    print(f"Inference time: {end_time - start_time} seconds")

start = time.time()
model = model.merge_and_unload()
print("Merge and Unload: ", time.time() - start)
model.eval()
with torch.no_grad():
    start_time = time.time()
    for _ in range(5):
        tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True)
    end_time = time.time()
    print(f"Inference time: {end_time - start_time} seconds")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Inference time: 114.71072840690613 seconds
# Change Adapter:  0.003210306167602539
# Inference time: 134.60648274421692 seconds
# Merge and Unload:  6.13152813911438
# Inference time: 126.51704168319702 seconds

# %% [markdown]
# ### Step 8:
# Try the fine tuned model on the same example again to see the learning progress:

# %%
model.eval()
with torch.no_grad():
    print(tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True))


model.eval()
with torch.no_grad():
    print(tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 model.eval()
#       2 with torch.no_grad():
# ----> 3     print(tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True))
#
# NameError: name 'model_input' is not defined

# %% [markdown]
# ## Load fine-tuned model

# %%
import torch
from peft import PeftModel    
from transformers import AutoModelForCausalLM, AutoTokenizer, LlamaTokenizer, StoppingCriteria, StoppingCriteriaList, TextIteratorStreamer

setting = 1
if setting ==0:
    model_name = "../llama/hugging_face_weights/base/13B"
    adapters_name = "tmp/llama-output-13b-r-16"
else:
    model_name = "../llama/hugging_face_weights/base/7B"
    adapters_name = "tmp/llama-output-7b-r-8"
print(f"Starting to load the model {model_name} into memory")

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    # load_in_4bit=True,
    torch_dtype=torch.bfloat16,
    device_map={"": 0}
)
model = PeftModel.from_pretrained(model, adapters_name)
model = model.merge_and_unload()
tokenizer = LlamaTokenizer.from_pretrained(model_name)
tokenizer.bos_token_id = 1

stop_token_ids = [0]

print(f"Successfully loaded the model {model_name} into memory")
# Out:
# Starting to load the model ../llama/hugging_face_weights/base/7B into memory
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Successfully loaded the model ../llama/hugging_face_weights/base/7B into memory

# %%
from configs.datasets import receipt_dataset

# %%
model.eval()
with torch.no_grad():
    print(tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True))

# %%
import json
import torch
import time
import pandas as pd
from pathlib import Path
import os
import sys
from utils.dataset_utils import get_preprocessed_dataset
from configs.datasets import samsum_dataset, receipt_dataset

from ft_datasets.receipt_dataset import format


def evaluate(model, tokenizer, dataset_config):
    df_columns = ["file_name", "key", "gt", "prediction", "correct"]
    eval_df = pd.DataFrame(columns=df_columns)
    dataset = get_preprocessed_dataset(tokenizer, dataset_config, 'val')
    model.eval()
    print("inside evaluate")
    print("dataset length: ", len(dataset))
    for i in range(len(dataset)):
        print(i)
        sample_df = pd.DataFrame(columns=df_columns)
        ann = dataset.ann[i]
        correct = ann["output"]
        name = ann["fn"]

        sample_df["file_name"] = name
        eval_prompt = format.format_map(ann)
        
        # store all prediction time
        time_list = []
        with torch.no_grad():
            model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
            # measure how long prediction is taking
            start = time.time()
            out = tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True)
            end = time.time()
            time_list.append(end - start)

            # read output as json
            try:
                json_output = json.loads(out)
                json_correct = json.load(correct)
            except:
                print("failed to load json on sample: ", name)
                print(out)
                json_output = None
                json_correct = None

            if json_output is not None:
                for key in json_output:
                    sample_df["key"] = key
                    sample_df["gt"] = json_correct.get(key, None)
                    sample_df["prediction"] = json_output[key]
                    sample_df["correct"] = json_output[key] == json_correct.get(key, None)
                    eval_df = eval_df.append(sample_df, ignore_index=True)

    print("Average prediction time: ", sum(time_list)/len(time_list))
    print("Variance of prediction time: ", sum([(x - sum(time_list)/len(time_list))**2 for x in time_list])/len(time_list))

    return eval_df

# %%
eval_df = evaluate(model, tokenizer, receipt_dataset)
# Out:
# running on partition val; there are 40 samples
# inside evaluate
# dataset length:  40
# 0
# failed to load json on sample:  202307_nttd_請求書_テンプレート-003_郵送.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 〒	650-0031
# 兵庫県神戸市中央区東町○○○-〇
# 請求先株式会社	御中
# 御請求書
# 請求番号:	0000000001
# 請求日:	2021年12月20日
# 利用月:	株式会社請求元	2021年12月分
# 登録番号: T1223334444555
# 件名:テスト請求書
# TEL
# FAX
# Mail
# 担当者
# 合計金額	¥1,000-	(税込)
# 日付	項目名	数量	単価	税率	金額
# 12月10日	小麦粉	1,000	8%	1,000
# 小計	¥1,000
# 消費税(8%)	¥80
# 消費税(10%)	¥0
# 合計	¥1,000
# 税率別内訳 税抜金額
# 10%対象	¥0
# 軽減8%対象	¥1,000
# 備考:
# お支払い条件:
# 第1振込先
# 振込先	銀行名	みずほ銀行(0001)	支店名	東大阪支店	(484)
# 科目	普通	口座番号	1234567
# 口座名義	テキカクショ(カ
# 第2振込先
# 振込先	銀行名	支店名
# 科目	口座番号
# 口座名義
# 支払期限:2024/1/15
#
#
#  ### Json Output:
#  登録番号 T1223334444555
# 請求額(8%税込) 1,000
# 請求額(10%税込) 0
# タイトル請求書[登録番号 T1223334444555]
# 請求番号 0000000001
# 請求日付 2021年12月20日
# 請求者会社名:株式会社請求元
# 請求者住所:〒650-0031 兵庫県神戸市中央区東町○○○-〇
# 請求者電話番号:XXXX-XXXX-XXXX
# 支払者会社名:請求先株式会社
# 請求年月:2021年12月分
# 合計請求額(税込) 1,000
# 支払通貨:¥
# 消費税額(10%) 0
# 消費税額(8%) 80
# 合計請求額(税抜) 1,000
# 消費税額(10%) 0
# 消費税額(8%) 1,000
# 支払期日 2024/1/15
# 口座の種類支払者名義カカ(カ
# 口座番号 1234567
# 銀行名支店名 東大阪支店(みずほ銀行(0001)
# 登録番号 T1223334444555(税関)
# 請求額(10%税込) 0(税関)
# 請求額(8%税込) 1,000(税関)
# 消費税額(10%) 0(税関)
# 消費税額(8%) 1,000(税関)
#
# 1
# failed to load json on sample:  202307_nttd_川口土建指定請求書用紙（数式有り）.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 伝票番号
# 12月分 請 求 書
# 業者コード	2	56	請求年月日	2021.12.06
# 332-0012	インボイス登録番号	T 1234567890123
# 住所	埼玉県川口市本町4丁目11番6号
# 会社名	株式会社米倉建設	印
# 代表者名	米倉 義永
# TEL	048-224-5111	FAX	048-224-5118	(税抜)
# 川口土木建築工業株式会社 殿
# 下記の通り請求します。
# 工事番号	902	700	2	注文番号	0	既受領額	100,000
# 現場名	(仮称)板橋区小豆沢三丁目計画	請負金額	(税抜)	2,232,122	今回請求額	100,000
# 請求額(税込)	2,412,691	月末現在出来高	合計	200,000
# 20.0%	発注残額	2,032,122
# 工種	工事内容	数量	単価	金額	備考
# 100101	試掘工事	1.0	100,000	100,000
# 12311	ああああ*	2.0	12,321,412	2,132,122
# 支払期限:2023/7/7	税率	合計	2,132,122	請求額(税込)
# 8%	消費税額等	170,569	2,302,691
# 税率	合計	100,000	請求額(税込)
# 10%	消費税額等	10,000	110,000
# 月末現在出来高	決定金額	消費税額等	支払済額
# 査定欄欄	今回支払
# 出来高金額	合計
# 12000	未成工事支出金	13600	83150
# 材料及び貯蔵品	福利厚生費	発注残額
# 工種	金額	82101	材料費	83160	修繕維持費
# 82102	労務費	83170	事務用品費	92500	補修費
# 82103	外注費	83180
# 82104	通信交通費
# 仮設経費	83200	調査研究費
# 82106	83270
# 運搬費	租税公課
# 82107	機械等経費	83280	保険料
# 82116	福利厚生費	83300	雑費
# 82117
# 事務用品費
# 合計	82122
# 雑費
# 備考	振込先情報: 三井住友銀行 豊橋支店 当座	4544222	トウザフリコミサキ
# 社長	部長	部長	次長	課長	主任	工事長	所長	副所長	主任	経理	No.
# 1
#
#
#  ### Json Output:
#  請求額(10%税込) 110,000
# 請求額(8%税込) 170,569
# 登録番号 T 1234567890123
# 消費税額(10%) 10,000
# 消費税額(8%) 170,569
# 銀行名称 三井住友銀行
# 銀行支店名 豊橋支店
# 口座の種類 当座
# 口座番号 4544222
# 口座名義 請求者会社名
# 支払通貨 円
# 2
# failed to load json on sample:  202307_nttd_三神工業㈱　指定請求書.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書(6月
# ①貴社控
# 2022年06月末日締
# 三神工業株式会社 御中
# 事業者登録番号	T1234567891000
# 名請求元株式会社
# 所在地
# TEL ・FAX
# 振込先
# 銀行名	みずほ銀行	口座番号	1234567
# 支店名	東大阪支店	口座名義	テキカクセイキュウショ(カ
# 科目	普通	支払期限	2023/7/31
# 工事名	新築工事	作業所担当
# 工事番号	xxxxx	注文番号	xxxxx-xx-xx	契約金額	123,000,000
# 金 額
# ex別紙明細書通り	10,000,000
# ex冷媒配管工事・ダクト改修工事 等
# 出来高合計	10,000,000
# 前回迄請求金額	8,000,000
# 引	a-b	2,000,000
# 消費税	с×税率	10%	800,000
# 消 費 税 с×税率	軽減8%
# 今回請求金額	2,800,000
# 注文残高	113,000,000
# 税率別内訳	税抜金額
# 10%対象	¥10,000,000
# 軽減8%対象
#
#
#  ### Json Output:
#  請求額(税込)2,800,000
#  請求額(税抜)10,000,000
#  支払者名義(口座名義)テキカクセイキュウショ(カ
# 登録番号 T1234567891000
# タイトル 請求書(6月
# 銀行名 みずほ銀行
# 口座番号 1234567
# 支店名 東大阪支店
# 口座名義 テキカクセイキュウショ(カ
# 3
# failed to load json on sample:  202307_nttd_パターン３_請求先_請求先会社.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書
# 請求先会社 御中
# 請求日:2023/07/06	登録番号:T1234567890123
# 発行者:TTデータ
# 住所:〒789-0001	テスト県テスト市テスト町4-5 テストビル	西棟A101
# 電話番号:088-888-5555
# メールアドレス:detarame@detarame.com
# 振込期限:2023/07/07
# 振込先情報:テスト銀行 テスト支店 普通 0123456
# 備考:備考欄にいろいろな補足を記載でもフル桁まではいれない
# ご請求額:34,191円(税込)
# 取引日付	品目	単価	数量	消費税率	金額(税抜)
# 2023/07/04	食料品1	600	8%	1,200
# 2023/07/01	食料品2	150	10%	450
# 2023/07/01	日用品1	30,000	8%	30,000
# 税抜き金額	消費税額
# 8%対象計	31,200	2,496
# 10%対象計	450	45
# 総額	31,650	2,541
# 1/1
#
#
#  ### Json Output:
#  請求額(8%税込):31,200(1000000(税額3120000,請求額31,650000)
# 請求額(10%税込):450(1000000(税額450000,請求額31,650000)
# 登録番号: T1234567890123(登録番号)
# 請求日付: 2023/07/06(請求日付)
# 請求者会社名: TTデータ(請求者会社名)
# 請求者住所:〒789-0001(請求者住所)
# 請求者電話番号: 088-888-5555(請求者電話番号)
# 請求者メールアドレス: detarame@detarame.com(請求者メールアドレス)
# タイトル:請求書(請求書タイトル)
# 支払期日: 2023/07/07(支払期日)
# 銀行名:テスト銀行(銀行名)
# 銀行支店名:テスト支店(銀行支店名)
# 口座の種類:普通(口座の種類)
# 口座番号: 0123456(口座番号)
# 口座名義:請求者名義(口座名義)
# 請求額(税込):34,191(請求額(税込))
# 消費税額(10%):45(消費税額(10%))
# 消費税額(8%):2,496(消費税額(8%))
# 登録番号の請求者会社名: T1234567890123 TTデータ(登録番号の請求者会社名)
# 消費税額(10%):45(消費税額(10%))(消費税額(10%))
# 4
# failed to load json on sample:  202307_nttd_パターン２_請求先_取引太郎.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書
# 取引太郎 様
# 請求日:2023/07/06	登録番号:T1234567890123
# 発行者:株式会社A
# 住所:〒222-5678	神奈川県横浜市データ2-3-1
# 振込期限:2023/09/05
# 振込先情報:データ銀行 データ支店 当座 1111111
# 備考:-
# 電話番号:080-5555-8888
# メールアドレス:dummy@xxxxxxxx.ne.jp
# ご請求額:80,920円(税込)
# 取引日付	品目	単価	数量	消費税率	金額(税抜)
# 2023/06/10	取引物1	3,000	8%	24,000
# 2023/06/10	取引物2	10,000	10%	50,000
# 税抜き金額	消費税額
# 8%対象計	24,000	1,920
# 10%対象計	50,000	5,000
# 総額	74,000	6,920
# 1/1
#
#
#  ### Json Output:
#  請求額(80,920円(税込)。消費税額(6,920円。
# 5
# failed to load json on sample:  202307_nttd_パターン１_請求先_株式会社テスト.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書
# 株式会社テスト 御中
# 請求日:2023/07/06	登録番号:T1234567890123
# 発行者:NTTデータ
# 住所:〒100-1234	東京都港区試験町1-1-1試験マンション	202号室
# 電話番号:03-1234-5678
# メールアドレス:test@dummy.co.jp
# 振込期限:2023/08/31
# 振込先情報:テスト銀行 テスト支店 普通 0123456
# 備考:備考欄の記載
# ご請求額:1,080,000円(税込)
# 取引日付	品目	単価	数量	消費税率	金額(税抜)
# 2023/07/04	製品1	1,000,000	8%	1,000,000
# 税抜き金額	消費税額
# 8%対象計	1,000,000	80,000
# 10%対象計
# 総額	1,000,000	80,000
# 1/1
#
#
#  ### Json Output:
#  請求額(10%税込):1,000,000
# 請求額(8%税込):1,000,000
# 消費税額(10%税込):0
# 消費税額(8%税込):80,000
# 6
# failed to load json on sample:  202307_nttd_seikyuusyo_kouji_invoice_202303.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書及び内訳明細
# (6月分)
# 工事名称
# テスト工事1 テスト現場
# ①契約金額
# (税率10%対象)	1231123	円(うち、消費税額等 123123円)
# ①契約金額
# (税率8%対象)	123	円(うち、消費税額等 23円)
# ②前払金額	円	⑥	今回請求金額	1234123311円
# ③出来高金額	円	⑦	(①-②-⑤-⑥)
# ④	出来高の10分の9	円	契約金残額	円
# ⑤	1回目	円	契約番号
# 部分払	2回目	円	検収日	年 月	日
# 済額	3回目	円	(※工事の場合は検査済証の発行日)
# 請求書
# 金額
# (税込)	2	3	4	1233
# 円
# (うち、消費税額等	円)
# 上記の金額を請求します。	※支払期限:2023年6月30日まで
# 5年3月2日
# 明石市長	様
# 住	所 東京都港区1-1
# 株式会社請求元
# 氏 名	請求元 太郎
# 登録番号	T1241231251267
# (適格請求書発行事業者)
# 振込先情報
# 三井住友銀行	豊橋支店 普通 1234111	セイキュウモトメイギ
# (注1)	部分払金の限度額	③×	(9/10-②/①)-⑤
# (注2)	④=③×(9/10-②/①)
#
#
#  ### Json Output:
#  請求額(10%税込) :1231123(消費税額123123)
# 請求額(8%税込) :123
# 登録番号 T1241231251267
# 請求者会社名株式会社請求元
# 請求者住所東京都港区1-1
# 支払者会社名 明石市長様
# 支払期日 2023年6月30日
# 請求年月 6月分
# 銀行名、支店名、口座名義(普通) SEIKYU MOTOMOTE GIN'YA(T1234111)銀行支店名豊橋支店
# 消費税額(10%) 123123(10%×123123)
# 消費税額(8%) 23
# 7
# failed to load json on sample:  202307_nttd_seikyuuippanekuseru.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 年度	所属	ST試験	検収年月日	検収印	備品管理簿	記帳印
# 請求書
# 百	千
# 金額	1	000
# [内訳]
# 品	名	数量	単価	金 額	摘	要
# 小麦粉	1000円	1000円
# 小計
# 消費税(8%)	¥80
# 消費税(10%)	¥0
# 合計	¥1,000
# 税率別内訳 税抜金額
# 10%対象	¥0
# 軽減8%対象¥1,000
# 債権者	コード
# 支払方法	10
# 請求番号	123
# 上記のとおり請求いたします。	なお,次のとおり支払をお願いします。
# (希望する方を○で囲みます。)
# 10	口座振替	債権者登録口座(債権者コード)へ振替えて下さい。
# 20 現金払
# 新潟市長	様
# 住所
# 氏名	請求元株式会社
# 登録番号:	T1223334444555
# 口座振替申込書(債権者登録のない方のみご記入願います。)
# 2023年7	月
# 利用月:7月分
# 電話
# 金融機関名
# みずほ銀行(0001)
# 支店名等
# 東大阪支店(484)
# 預金種目
# フリガナ
# 普通
# 口座番号
# 4 5
# テキカクセイキュウショ(カ
# 口座名義
# 支払期限:2023年8月31日
# 適格請求書株式会社
#
#
#  ### Json Output:
#  請求額(10%税込) 1,000000
# 請求額(8%税込)1,000000
# 消費税額(10%)0
# 消費税額(8%)80
# 8
# failed to load json on sample:  202307_nttd_seikyusyoo.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書兼支払依頼明細書(7月分)
# 株式会社 アネスト 御中
# 適格請求書発行事業者登録番号	T1223334444555	2023年7月7日
# 請求者	請求元株式会社	振	みずほ	銀行	東大阪	支店
# 住所	普通	口座
# 込	番号	1234567
# ⑳	フリガナ	テキカクセイキュウショ(カ
# TEL・FAX	先	口座名義 適格請求書株式会社
# ・太枠内のみご記入下さい。	・適格請求書発行事業者登録番号をお持ちの場合は必ず記入して下さい。お持ちでない場合は"無し"と明記して下さい。
# 内容	請	求 金	額
# 内	工事1	50,000
# 訳
# 小	計	50,000
# 消費税	5,000
# 税 込 合 計 [A]	55,000
# 税率別内訳 税抜金額
# 10%対象	軽減8%対象	¥50,000	¥0
# 支払 金 額 [A-B]	¥55,000
# 振	込	¥55,000	業者名
# 支払期限	2023/7/31	コード
# 本支店	作業所	支払日
# 2022/11/01改定
#
#
#  ### Json Output:
#  請求額(税込)55,000(55,000(税抜)50,000)
# 支払通貨[JPY]55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000(55,000
# 9
# failed to load json on sample:  202307_nttd_seikyusyo_invoice_excel.pdf-4
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求年月日を入力	(例:2023/10/20と入力)
# 株式会社 村上組 御中	下記の通り請求いたします。
# 請求書
# 記入例
# 令和5年10月20日
# 工事名称
# ○○建築工事
# 工事名称・工事コードが不明な	場合はお問い合わせ下さい。
# 役員	役員	役員	部長┃課長	担当者
# 工事 コード	100000
# 注文 No.
# 0
# C
# 取引先コードが不明な場合はお問い合わせ	下さい。
# 令和5年10月1日以降の発行分には登
# 取引先コード	1	234	録番号を記入して下さい。	消費税免税事業者は記載不要です。
# 適格請求書登録番号	T1-2345-6789-0123
# 請求者	住所	会社名	青森県弘前市藤代一丁目2-1	株式会社 村上組	社印
# 代表取締役社長	村上公洋
# TEL	振込先	0172-35-6111	FAX	0172-35-6115
# ○○銀行	○○支店	普通1234567
# 契 約 金 額(税込)	1	1	0	59	6
# 契約金額がある場合は	入力して下さい。
# 請 求額 合 計(税込)	110596
# F(請求額合計)が自動	入力されます。
# 支払決定額
# 出来高払の場合、累計出来	高に対する請求額比率	(100%の場合は100、90%の	場合は90)を入力して下さい。
# 請求者欄はゴム印でも構いません。	提出用請求書を印刷後に会社印を押し
# て提出して下さい。
# 今回迄の累計出来高	A
# 100	600
# 月日	品名・規格	数量	単価	消	金	額
# 10	建築工事	1.0	式	99,800	99,800
# 10	飲料水	2.0個	100	200
# 10	印紙代	3.0	枚	200	600
# 請求内訳を入力すると自動	請求内訳を入力して下さい。	この欄には、軽減税率8%
# 項目が多い場合は内訳別	適用のものは「8」、消費税
# 入力されます。	又は消費税率ごとに分けて	紙をお使い下さい。	が付かないもの(不課税・
# 税抜金額計、対応する消費	又はここには記入せず、内	非課税)は「0」を記入して
# 税額を直接入力して下さい。	訳を別紙(貴社様式)にて添	下さい。
# 同上に対する請求額
# A・B・C欄は出来高払	の場合のみ入力して	下さい。
# 00%
# 100
# 600
# 前回迄の既請求累計
# 0
# 今回請求額	B-C	100	6	0	0
# 消費税	6	996
# 請求額合計	D+E	1	10	59	6
# 8%	対象計(税抜)	消費税
# 10%	対象計(税抜)	消費税
# 消費税対象外	消費税
# 請求額計(税抜)	消費税計
# 請求書発行について
# ●請求書は毎月20日締、提出は25日迄です。	●提出用請求書はA4サイズにて印刷して下さい。	●複数の工事を受注されている場合には、各工事名ごとに請求書を提出して下さい。	●各項目自動計算となっておりますが、金額訂正が必要な場合は直接入力して下さい。	●請求書は手書きでの提出も可能です。
# *「消」欄には、軽減8%の場合は「8」、消費税がかからない場合は「0」記入して下さい。	*締切は毎月20日 提出は25日迄 *太枠欄は記入不要	*工事名称、工事コード取引先コードは必ず
#
#
#  ### Json Output:
#  請求額(10%税込) 596000000000000000
# タイトル 請求額(8%税込) 60000000000000000
# 10
# failed to load json on sample:  202307_nttd_seikyusyo_invoice_excel.pdf-3
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 内訳別紙
# 月日	品名・規格	数量	単価	消	金	額
# 月日	品名・規格	数量	単価	消	金	額
#
#
#  ### Json Output:
#  請求額(10%税込) : 5,40000000000
# 11
# failed to load json on sample:  202307_nttd_seikyusyo_invoice_excel.pdf-2
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 株式会社 村上組 御中	下記の通り請求いたします。
# 請求書
# 令和5年10月20日
# 工事名称	建築工事
# 役員	役員	役員	部長	課長	担当者
# 工事 コード	100000	-	00
# 注文 No.
# 取引先コード	1	234
# 適格請求書登録番号	T1-2345-6789-0123
# 請求者	住所	会社名	請求元株式会社
# 代表取締役社長	試験太郎
# TEL	東大阪支店	FAX
# 振込先 みずほ銀行	普通1234567 テキカクセイ
# 契 約 金 額(税込)
# 請 求額 合 計(税込)	110	596
# 支払決定額
# 今回迄の累計出来高	A	1	0	0	00
# 同上に対する請求額	A×100%	10	0	00
# 前回迄の既請求累計	0
# 今回請求額	B-C	100	600
# 消費税	6	996
# 請求額合計	D+E	110	596
# 月日	品名・規格	数量	単価	消	金	額
# 10	建築工事	1.0	式	99,800	99,800
# 10	飲料水	2.0個	100	200
# 10	印紙代	3.0枚	200	600
# 8%	対象計(税抜)	消費税
# 10%	対象計(税抜)	消費税	80
# 消費税対象外	消費税
# 請求額計(税抜)	消費税計
# *「消」欄には、軽減8%の場合は「8」、消費税がかからない場合は「0」記入して下さい。	*締切は毎月20日 提出は25日迄 *太枠欄は記入不要	*工事名称、工事コード取引先コードは必ず
#
#
#  ### Json Output:
#  請求額(10%税込) 596
# 消費税額(10%) 600
# 請求額(8%税込) 99,800
# 消費税額(8%) 80
# 合計請求額(税込) 110
# 銀行名称 みずほ銀行
# 銀行支店名 東大阪支店
# 口座の種類 GM 普通
# 口座番号 1234567
# タイトル 請求書
# 支払者会社名 株式会社 村上組
# 12
# failed to load json on sample:  202307_nttd_seikyusyo_invoice_excel.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 株式会社 請求先	下記の通り請求いたします。	御中
# 請求書
# 請求月日	令和5年10月20	日
# 工事名称	建築工事
# 役員	役員	役員	部長	課長	担当者
# 工事コード	100000
# 注文 No.
# 00
# 取引先コード	1234
# 適格請求書登録番号	T1-2345-6789-0123
# 請求者	住所	会社名	請求元株式会社
# TEL	代表取締役社長	試験太郎
# FAX
# 振込先	みずほ銀行	東大阪支店	普通1234567	テキカクセイキュウショ(カ
# 契 約 金 額(税込)
# 請求額合計(税込)	110,596
# 利用月:9月	支払期限:2023/10/31
# 今回迄の累計出来高	A	10,000
# 同上に対する請求額	A×100%	10,000
# 前回迄の既請求累計
# 今回請求額	B-C	100,600
# 消費税	9,996
# 請求額合計	D+E	110,596
# 月日	品名・規格	数量	単価	消	金	額
# 10	建築工事	1.0	式	99,800	99,800
# 10	飲料水	2.0個	100	200
# 103	印紙代	3.0枚	200	600
# 8%	対象計(税抜)	200	消費税	16
# 10%	対象計(税抜)	99,800	消費税	9,980
# 消費税対象外	600	消費税
# 請求額計(税抜)	100,600	消費税計	9,996
# *「消」欄には、軽減8%の場合は「8」、消費税がかからない場合は「0」記入して下さい。	*締切は毎月20日 提出は25日迄 *太枠欄は記入不要	*工事名称、工事コード取引先コードは必ず記入して下さい。
#
#
#  ### Json Output:
#  請求額(10%税込) 99,800
# 消費税額(10%) 9,980
# 請求額(8%税込) 200
# 消費税額(8%) (8%税込) 16
# 消費税額 9,996
# 合計請求額(税込) 110,596
# タイトル:請求額(10%税込)、請求額(8%税込),消費税額(10%),消費税額(8%),合計請求額(税込),消費税額,請求額(10%税込),請求額(8%税込),消費税額(8%),請求額(10%税込),請求額(8%税込),消費税額(10%),消費税額(8%)
# 13
# failed to load json on sample:  202307_nttd_seikyusyo.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書(7月分)
# ※適格請求書(インボイス)発行事業者の登録を受けた場合入力してください。
# No.
# 伝票番号	取引先コード	登録番号※	T	123	1
# 工事コード	↓弊社と注文書・請書を取り交わした場合下記を入力してください。	住所
# 工事名	注文番号	会社名	株式会社請求元
# 契約額(税抜)	代表者名	印
# 請求期間	月日〜月日	前回迄請求額(税抜)	TEL	※取引先コードをお持ちの方は、	「銀行欄」記入の必要はありません。
# 発行日	2023年7月7日	今回請求額(税抜)	銀行名	三井住友銀行	支店名	豊橋支店
# 支払日	2023年7月30日	請求残高(税抜)	口座番号	当・(普
# 原価コード	工種・明細名	品	名	規 格	単位	数量	単価	金	額
# 工事1	品1	1,000	1,000
# 工事2	品2*	1,000	2,000
# 所長	連絡
# 小計8%(税抜)	1,000
# 小計10%(税抜)	2,000
# 消費税額(	%)	160
# 消費税額(	10	%)	100
# 合計	3,260
# 山﨑建設工業株式会社
#
#
#  ### Json Output:
#  請求額(8%税込) 1,000
# 請求額(10%税込) 2,000
# 合計請求額 3,260
# 銀行名 三井住友銀行
# 銀行支店名 豊橋支店
# 請求日付 5年7月7日
# 支払日付 5年7月30日
# 請求額(10%税抜) 1,000
# 請求額(8%税抜) 1,000
# 消費税額(10%) 100
# 消費税額(8%) 160
# 登録番号 T1231
# 14
# failed to load json on sample:  202307_nttd_seikyusho_10.pdf-4
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 納品書兼請求書
# 株式会社土木管理総合試験所	御中
# No.	123456
# 業者コード	1000
# 部署名	○○部 ××課
# 担当者名	土木太郎
# 住所	111	2222
# ○○県××市△△ 1-2-3
# 会社名	株式会社○○○○
# (支店名等)	××支店	印
# 登録番号	T8100001001234
# 担当者名	△△	△△
# TEL	026	123	4567	FAX	026	123	7891
# ○いち納品ごと作成し、納品時にご提出下さい。
# 押印忘れのないようご注意下さい。
# 振込先は、口座登録シートに記載していただいた口座となります。
# 振込先の変更が必要な場合は、弊社担当者までご連絡下さい。
# 納品年月日
# 2019年10月5日
# 拠点コード	業務コード	受付簿№.	件名(調査件名)
# 11	123456	市道○-〇〇〇〇号線道路改良工事
# 商品名	税率	数量	単位	税抜単価(円)	税抜金額(円)
# ○○○○試験	10%	式	10,000	10,000
# ××××調査	10%	式	10,000	10,000
# 10%
# △△△△レンタル(10/4〜10/5)	10%	日	5,000	10,000
# 上記サポート料	10%	5,000	10,000
# 上記基本料	10%	台	10,000	10,000
# 10%
# ○〇計	10%	台	2,000	10,000
# х×試験機	10%	台	10,000	10,000
# 10%
# コーヒー	8%	10	袋	500	5,000
# 煎茶ティーバッグ	8%	10	パック	500	5,000
# 10%
# 立替金(〇〇代)	非	式	10,000	10,000
# 10%
# 10%
# 税率	税抜金額(円)	消費税額(円)	税込金額(円)
# 小計	10%	70,000	7,000	77,000
# 小計	8%	10,000	800	10,800
# 小計	非	10,000	10,000
# 合計	90,000	7,800	97,800
# 源泉所得税(プラス金額で入力)	(源泉所得税計算式)	100,000円×10.21%	10,000
# 請求金額	87,800
# 連絡欄
#
#
#  ### Json Output:
#  請求額(8%税込) 10,000
# 請求額(10%税込) 70,000
# 消費税額(7%) 700
# 消費税額(8%) 500
# 合計請求額(税込) 90,000
# 銀行名義者名 株式会社○○○○
# 銀行支店名 ××支店
# 口座の種類(支払者口座) Cheque
# 口座番号 123456781234567
# 口座名義者名 会社名義者名 株式会社○○○○
# 登録番号 T8100001001234
# 消費税額(10%) 7,000
# 請求日付 5年10月5日
# 銀行名義者名(消費税額請求者) △△△△レンタル(10/4〜10/5)
# 請求額(10%税込) 10,000
# 消費税額(10%) 1000
# 請求額(10%税込) 2,000
# 消費税額(8%) 500
# 銀行支店名(消費税額請求者) ××支店
# 合計請求額(税抜) 10,000
# 15
# failed to load json on sample:  202307_nttd_seikyusho_10.pdf-3
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 納品書兼請求書
# 株式会社土木管理総合試験所	御中
# 発行日	2023/7/5
# 部署名
# 担当者名
# 住所
# 会社名	請求元株式会社
# ○いち納品ごと作成し、納品時にご提出下さい。	(支店名等)	⑪
# o	押印忘れのないようご注意下さい。	登録番号	T1234567890123
# o	振込先は、口座登録シートに記載していただいた口座となります。	担当者名
# 振込先の変更が必要な場合は、弊社担当者までご連絡下さい。	TEL	FAX
# 利用月
# 2023年7月
# 拠点コード	業務コード	受付簿№.	件名(調査件名)
# 商品名	税率	数量	単位	税抜単価(円)	税抜金額(円)
# テスト	10%	個	123	369
# 試験	8%	匹	500	3,500
# 10%
# 10%
# 10%
# 10%
# 10%
# 10%
# 税率	税抜金額(円)	消費税額(円)	税込金額(円)
# 小計	10%	369	36	405
# 小計	8%	3,500	280	3,780
# 小計	非
# 合計	3,869	316	4,185
# 源泉所得税(プラス金額で入力)	(源泉所得税計算式)
# 請求金額	4,185
# 連絡欄
# 振込銀行 みずほ銀行	東大阪支店(普)1234567	コーザメイギ
# 支払期限	2023年7月31日
# 伝票No.(
# 全6枚(3枚目)
#
#
#  ### Json Output:
#  請求額(8%税込) :3,500
# 請求額(10%税込) :369
# 登録番号 :T1234567890123
# 銀行名 :みずほ銀行
# 銀行支店名 :東大阪支店
# 口座の種類 :普
# 口座番号 :1234567
# 消費税額(10%) :36
# 消費税額(8%) :280
# 16
# failed to load json on sample:  202307_nttd_seikyukensyu.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求者控
# 工事名	コード
# 請求書兼検収報告書
# 当該請求(検収)No.
# 当月の検収総件数
# 請求年月日
# 2023	年
# ⑳ みらい建設工業株式会社 御中
# 下記のとおり請求致します。支払期限:2023/7/7
# 請求金額	¥123,412,121
# 取引先コード
# 000
# 住所
# 東京都港区1-1 株式会社請求元
# 氏名 請求元 太郎
# 12	12
# 登録番号T
# [請求内訳](10%)
# 名称・規格・期間	単位	数量	単価	金 額(単位:円)
# 竹刀	1,234	1,234
# 品2*	12,345	12,345
# 消費税	0%	8%	10%
# v	12,333
# 合計	25,912
# [請求内訳](8%)
# 名称・規格・期間	単位	数量	単価	金額	(単位:円)
# 竹刀4	1,234	12,321
# 品3*	12,345	2,222
# 消費税	0%	8%	10%	12,333
# 合計	26,876
# 発注№.	検収回数
# 回払
# 当初	請求検収額	当月	保留金額
# 発注額	増減	前月迄	支払条件
# 総計	総計	差引残高	A-B
# [当社検収金額]
# 工事費	消費税	合	備者
# 当社支払分
# 他社相殺分
# 合
# 振込先情報	三井住友銀行 豊橋支店支店 普通 4041123 フリコミサキ
# 決裁	審査	起案
# (注)当請求書を提出する取引先は、太枠の部分を作業所の指示に従って記入してください。
# みらい建設工業株式会社
#
#
#  ### Json Output:
#  請求額(8%税込)26,876
# 請求額(10%税込)25,912
# タイトル 請求者名/会社名 請求者控 工事名 請求書兼検収報告書 支払者会社名 請求番号 支払期日 請求年月日 請求者住所 電話番号 請求者会社名消費税額(8%)消費税額(10%)合計請求額(税込)支払者銀行名/支店名 銀行支払口座番号 口座の種類 口座番号 Fa ...
# 17
# failed to load json on sample:  202307_nttd_seikyu_zairyokeihi_20230328_P43のみ.pdf-43
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請 求 書(9月分)
# (材料・経費用)
# 佐藤工業株式会社
# 作業所	試験ビル	部・課	殿
# 主管	経理
# 整理番号
# 1311未成工事支出金
# 8141	部門原価
# 材料費
# 工種明細 ※整理用(任意)
# 工種	本体価格
# 佐藤工業使用欄
# 本体価格計
# 300	401
# 労務費
# 外注費	仮設経費	動力用水光熱費
# 工事	組織	佐藤工業使用欄
# 運搬費	機械等経費
# 設計費	従業員給料手当
# 法定福利費
# 福利厚生者
# 事務用品費
# 通信交通費	交際費(社外飲食費	交際費(その他
# 514
# 請求合計		30,600
# 上記のとおり請求いたします。
# 2019年	4月15日
# 寄付金	地代家賃
# 支払賃借料	受取賃借料
# 租税公課
# 保険料	労務管理費	労災保険料
# 所在地
# 会社名 請求元株式会社
# 代表者名	代表取締役社長あああ
# 電話
# 印
# 補償費	派遣社員
# アルバイト
# 積筒料
# 雑費
# 会計明細	※内訳記入用
# 科目	消費税区分	税込価格
# 税込価格計
# 仕入先コード	X2139999
# 登録番号	T012345789123
# 請求番号(任意)	※英数字8桁以内	BRTN7777
# 注文番号	14桁のうち9~12桁目を記入
# 日付	名称	仕様	消費税区分	単位	数量	単価	金額	備考
# 9/25	軽油代(8%)	200.000	60.00	12,000
# 10/3	軽油代(10%)	10%	200,000	60.00	12,000
# 10/15	軽油税	非課税	400.000	3.00	1,200
# 10/10	飲料水	8%(軽減税率)	10.000	300.00	3,000
# 1枚の請求書で明細欄が不足する場合は、記入例②を参照。
# 本体価格 計	28,200
# 税率毎集計	支払額	税抜金額	消費税等
# 10%	13,200	12,000	1,200
# 8%(軽減税率)	3,240	3,000	240
# 8%	12,960	12,000	960
# 非課税・不課税	1,200	1,200
# 合計	30,600	28,200	2,400
# 課税事業者仕入
# 振込先	銀行名	科目	みずほ銀行(000	普通	支店名	口座番号	東大阪支店
# 口座名義	1234567
# テキカクショ(カ
# 支払期限:2024/1/15
#
#
#  ### Json Output:
#  請求合計(税込) 30,600
# 支払者会社名 佐藤工業株式会社
# 請求年月 9月分
# タイトル 請求 書
# 請求者会社名 請求元株式会社
# 支払通貨 単位 ¥
# 支払期日 2019年4月15日
# 消費税額(10%) 1,200
# 消費税額(8%) 240
# 登録番号 T012345789123
# 請求番号 BRTN7777
# 口座の種類 普通
# 口座番号 1234567
# 口座名義 テキカクショ(カ
# 銀行名 みずほ銀行
# 銀行支店名 東大阪支店
# 消費税額(8%)(軽減税率) 3,000
# 請求者会社名の種類(株) FAIL
# 支払者会社名の種類(株) SSLLC
# 支払者名 経理
# 請求者住所 材料・経費用 168-1, 試験ビル, 東京都港区, 101-0052
# 請求者電話番号(「○○○○○」形式) 12345678
# 支払者電話番号(「○○○○○」形式) 12345678
# 支払者会社名の製品名(例) FAIL
# 18
# failed to load json on sample:  202307_nttd_keiyo-koukan_invoice.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 京葉工管株式会社 御中	請求書(7月分)
# 請求日	2023年7月7日
# 様	請求者
# 下記の通り請求いたします。
# 本体金額	10	000
# 消費税額	1	000
# 請求金額	11	000
# 住 所	〒
# 会社名	請求元株式会社	印
# 登録番号	T1223334444555
# 電話	FAX
# 税抜契約工事金額
# 前回迄出来高金額
# 今月出来高金額
# 総出来高金額
# 残契約工事金額
# 振込先	※支払期限:2023/7/31
# 銀行名	みずほ銀行
# 支店名	東大阪支店
# 口座番号	普通
# (フリガナ)	テキカクセイキュウショ(カ
# 口座名義	適格請求書株式会社
# 工事件名
# 月日	品名及び工事内容	単位	数量	税率	単価	金額
# 試験工事	式	10%	10,000	10,000
# 本 体	計	10,000
# 消費税	10%	(対象小計	10,000 )	端数調整	1,000
# 消費 税 8%	(対象小計	0)	端数調整
# 合	計	11,000
# 京葉工管使用欄
# 工事番号
# 伝票番号
# 業者名
# 立替払	相殺(税込)
# 京葉払	税抜
# 税込
# 請求書受付
# 20230310
#
#
#  ### Json Output:
#  請求額(10,000(税抜),11,000(税込)。銀行名義は、'適格請求書株式会社'で登録番号は'T1223334444555'。
# 19
# failed to load json on sample:  202307_nttd_invoice_seikyusho.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# <上下水道事業専用>
# 請求書(6月分)
# 横手市長 様
# 適格請求書発行事業者登録番号
# ↑インボイス制度の登録番号(13桁)がある場合はご記入ください。
# 請求年月日	令和5年6月30日
# 住	所 〒 013-0022
# 債	○○県○○市○○丁目0番0号
# 権	事業所名又は		横手商事株式会社
# 者	氏名又は	代表者氏名	代表取締役 横 手 太 郎
# 電 話 番 号 ○○○○-○○-○○○○
# T	12
# 発注課
# 水道課	下水道課	経営管理課
# 発行責任者(職・氏名)	営業部長 ○○○○○
# 電話番号	0○○○-○○-○○○0
# 発行担当者(職・氏名)	経理担当 ○○○○○
# 電話番号	0○○○-○○-○○○0
# 発注課にをしてください	不明な場合は記入不要です
# 請求書№	R04-12345-678	右の金額を請求します。
# ↑発行責任者、担当者は、必ずご記入ください。
# 支払期限:2023/7/7	まで
# 請求金額	¥9,880円
# ↑金額の頭に「¥」をご記入ください。
# 名称・規格	納入月日	数量	単位	単価	金額
# 品目A	2023/7/7	個	2,200	6,600
# 品目B	2023/7/7	個	1,100	2,200
# 品目C_※	2023/7/7	個	1,080	1,080
# ↑軽減税率対象のものは、その欄に「※」をご記入ください。	合計	9,880
# 適用税率ごとに区分して合計	10%対象	8,800 円	内 消費税額	800円
# した請求金額及び消費税額	8%対象	1,080 円	内 消費税額	80円
# 非課税・不課税	0円	内 消費税額
# 口	金融機関名	支店名
# 座振込先	三井住友	1銀行農協	豊橋支店	フリガナ	ヨコテショウジ(カ
# 2金庫 4その他
# 預金種目	口座番号
# 普通 ・貯蓄
# 当座	0123456	口座名義	横手商事株式会社
# ・「発行責任者」は代表取締役、支店長等請求権限のある方、	・インボイス制度とは、消費税の適格請求書等保存方式をいいます。
#
#
#  ### Json Output:
#  請求額(8%税込)1,080円
# 請求額(10%税込)8,800円
# 消費税額(8%)80円
# 消費税額(10%)800円
# 20
# failed to load json on sample:  202307_nttd_invoice_01.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書
# 株式会社 オサコー建設	御中
# 令和###年7月7日
# 7月分
# コード番号	12345	支払日	2023年	7月	31日	No.
# 請	住所	〒
# 求	商号又は名称	印
# 者	氏名	請求元株式会社
# 電話	FAX
# 振込銀行	みずほ	銀行	東大阪
# テキカクセイキュウショ(カ	支店	普通
# フリガナ
# 口座名義	適格請求書株式会社	口座	番号	1234567
# インボイス 登録番号	T	22	3	3	44	45
# 工事番号	工 事	名	注文番号
# 123	test	001
# 金 額	摘 要
# A	請負契	約	額	50,000
# B	精算増減額	30,000
# C	総請負額(A+B)	20,000
# D	今回出来高金額	0
# 消費税10%対象	100,000
# G	消費税8%対象	0
# G	今回請求額(E+F)	100,000
# H	前回迄請求額	0
# 差引残額【C-(G+H)】	0
# 請求金額	¥110,000	(税込)
# 今回請求額
# ¥100,000
# 消費 税額 10%
# ¥10,000
# 消費税額 8 %
# ¥0
# 上記の通り請求いたします。
# ◎請求書は1工事現場毎に作成し、2工事現場以上の場合は必ず総括表を提出して下さい。
# 確認印	担当
#
#
#  ### Json Output:
#  請求額(税込)110,000(50,000(請負額(123,000,消費税10%対象100,000,消費税8%対象0, 合計請求額110,000,登録番号 T22333444444445.
# 21
# failed to load json on sample:  202307_nttd_invoice20201204-tax10.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請 求 書(5月分)
# 馬淵建設株式会社	御中
# p-1
# 取引先→作業所→本社(控)
# 請求年月日
# 2018年5月10日
# 取引先コード
# 999999999
# 〒	232-0018
# 住所	神奈川県横浜市○○区△△町2-26
# 会社名 請求元株式会社
# 担当者名
# TEL	045-xxx-xxxx
# FAX	045-xxx-yyyy
# 下記の通り、御請求申し上げます。
# 請求金額(税込)
# 540,000円
# 本体価格(税抜)
# 500,000円
# 消費税額
# 40,000円
# 印
# 下欄は、【注文契約	】の場合だけ御記入下さい。
# 契約 or 契約外
# 契約
# 注文番号	注文親番	注文金額(税抜)	前回迄の請求額	今回の請求額	契約残高
# 120	170500010	1,500,000円	500,000円	500,000円	500,000円
# (当社使用欄)
# 工事コード	社内略称
# 工事種類または品名	数量	単位	単価	額(税抜)	税区分	消費税	工種	科目要素	額(税抜)
# 10	あああ	本	250,000	250,000	20,000
# 10	いいいいいい	本	50,000	150,000	12,000
# 10	ううううう	本	100,000	100,000	8,000
# (この請求書は2部1組で印刷し、取引先(控)を除いた1部を馬淵建設(株)に提出して下さい。)
# 所長	主任・係員
# 金額(税抜)頁小計
# 500,000
# 消費税 頁小計
# 40,000
# ※上記欄は必要に	応じて使用する。
# 本体価格(税抜)
# 消費税額
# 請求金額(税込)
# 振込先	銀行名	みずほ銀行(0001)	東大阪支店	科目	口座名義	普通	口座番号
# テキカクセイキュウショ(カ	1234567
# 金額(税抜)合計
# 500,000
# 消費税合計
# 40,000
#
#
#  ### Json Output:
#  請求額(10%税込)": “500,000”
# "請求額(8%税込)": “500,000”
# "登録番号": "T1221234555555"
# "請求日付": "2018年5月10日"
# "タイトル": "請 求 書"
# "支払者会社名": "馬淵建設株式会社"
# "請求年月": "5月分"
# "支払通貨": "円"
# "合計請求額(税込)": "540,000"
# "消費税額": "40,000"
# "合計請求額(税抜)": "500,000"
# "請求者会社名": "請求元株式会社"
# "請求者住所": "〒 232-0018\n神奈川県横浜市○○区△△町2-26"
# "請求者電話番号": "045-xxx-xxxx"
# "請求者FAX": "045-xxx-yyyy"
# "消費税額(8%)": "12,000"
# "消費税額(10%)": "20,000"
# "口座の種類": "普通"
# "口座番号": "1234567"
# "口座名義": "テキカクセイキュウショ(カ"
# "支払期日": "2018年5月15日"
# "請求者会社分野": "建築"
# "請求者会社size": "中規模"
# "請求者電話番号(支払者会社)": "N/A"
# "登録番号支援サイト": "https://touken.support.hikvision.com/"
# "請求者住所(支払者会社)": "〒 232-0018"
# "請求者FAX(支払者会社)": "N/A"
# 22
# failed to load json on sample:  202307_nttd_invoice02_excel.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 令和4年11月20日
# 請 求 書	(11月分)
# 株式会社大原組	御中
# *大原組 支払条件
# 当月20日締め 当月末必着 翌月末支払(現金100%)
# 下記の通りご請求申し上げます。
# 御請求額	¥110,000
# 登録番号:T1223334444555
# 工事名/工事内容	数量	単位	契約	金額(税抜き)	消費税	税込金額	備考
# test	式	¥100,000	¥10,000	¥110,000
# 税率別内訳	税抜金額
# 10%対象	########
# 軽減8%対象 0
# 小計	¥100,000
# 消費税(10%)	¥10,000
# 消費税(8%)
# 合計	¥110,000
# お振込先:	みずほ銀行	東大阪支店	普通	1234567	テキカクセイキュウショ(カ
# 支払期限:2024/1/15
# ※㈱大原組	使用欄
# 専務	経理課長	経理担当
#
#
#  ### Json Output:
#  請求額(8%税込): 0
# 請求額(10%税込): Z100,000
# 消費税額(10%): Z10,000
# 消費税額(8%): Z0
# タイトル:請求書(11月分)
# 23
# failed to load json on sample:  202307_nttd_excel_shitei-Invoice.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書	(7月分)
# 6 年 30 月期限
# 発行日 2023/7/7
# 取引先コード
# (〒
# 住所	東京都港区1-1
# 社名	株式会社請求元
# TEL
# FAX
# 日本装芸株式会社 御中
# 下記の通り請求いたします。
# 現場名	テスト現場
# 注文内容
# 金融機関コード
# 振込先	三井住友銀行 銀行	豊橋	支)
# (普通)・当座	口座番号(	1245111
# フリガナ	フリコミサキ タロウ
# 口座名	振込先 太郎
# 今回請求金額
# 項目	金	額	累計出来高
# 税抜金額	31,214
# 消費税額	212	%
# 税込金額	121,111
# *注文書がある場合は、下記にご記入ください。	注文番号は注文書右上の番号です。
# *太枠内のみ貴社にてご記入ください。
# *毎月15日締切、20日迄に本社総務経理部に提出してください。
# (以降は翌月の扱いになります)
# *請求書の日付は必ず15日にしてください。
# *必ず社印を捺印してください。
# *内訳明細書(御社書式)を必ず添付してください。
# 注文番号
# 契約金額(税込)
# 既入金額
# 内訳表
# 支払条件	現金	%	手形	%
# 金	額	数量	単価	単位	税率	金額
# 品	00
# 品名З	10	00	10	20
# 8%対象額	¥11,222	(内消費税:¥2
# 10%対象額	¥12,344	内消費税:¥12
# 合計	¥121,111
# 実行 予算 No.
# 査定印	(担当印)
#
#
#  ### Json Output:
#  請求額(10%税込) 12,344(12%税込) 11,222消費税額(8%)2 Tax(2%) 2支払通貨手形ページ番号 T1タロウ銀行支店名豊橋支店支払期日請求年月5月・10月・15日締切・20日迄請求者会社名株式会社請求元口座の種類(タイトル)普通口座口座番号1245111口座名振込先太郎消費税額(10%)12支払者日本装芸株式会社タロウ銀行支店名銀行三井住友銀行登録番号(T ...
# 24
# failed to load json on sample:  202307_nttd_e377a6763f92eb351e17f1397ecf55fb.pdf-3
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 和光建設株式会社御中	・下記の通り御請求申し上げます。	請 求 書(1月分)	契約分
# 円也	支払期限:2013年2月末日
# 取引先	コード	1	23456
# 請求日 2013年1月30日
# 事業者登録番号	T1223334444555
# 住	所	さいたま市○○区△△町1-15-1
# 会社名	請求元 株式会社
# 代表者	電	代表取締役 ○△	△雄
# 話	TEL048-000-0000
# 請求金額 ¥	273900	0
# 工事名称
# ビル新築工事
# 月日	単位	単価	品名・工種	数量
# 注文書	(税抜)	金額	(税抜)
# 2013-103-001	履歴
# No.	No.	01
# 工事
# 種目	舗装工事
# 契約工事価格	1.0	式	10,000,000
# A	今月迄の出来高合計	41.7	%	4,170,000
# B	今回請求可能額(A× %)	90.0	%	3,753,000
# c	前月迄の既領収金額	1.0	式	1,260,000
# D	B-C	2,493,000
# E	今回請求額 計(端数切捨て)	1.0	式	2,490,000
# F	今回消費税額(8%)	0
# G	今回消費税額(10%)	249,000
# H	今回請求額 計	2,739,000
# 振込先	引去処理欄	(赤文字・番号↑指示)	消費税
# 銀行名	支店名	①	は注文書No.	取引先名	8%対象	¥0
# みずほ銀行	東大阪支店	②	は注文書o.	取引先名	より	支払	10%対象	¥2,490,000
# 科目	③	は注文書No.	取引先名
# 普通	④	は注文書No.	取引先名	備考
# 口座番号	役	経	管	担当者	No.
# 1234567
# 口座名義	テキカクセイキュウショ(カ	員	理	理	担当部
# ①取引先コード、住所氏名は貴社で記入	②請求内訳欄が不足する場合は貴社請求内訳書添付	③請求書は月末締切、翌月5日必着	④提出は1部、貴社で控えを保管下さい。⑤	枠内は記入しないでください
#
#
#  ### Json Output:
#  請求額(10%税込) 2,490,000(2,493,000(10%税込) - 3,000(8%税込) =)
# 銀行名支店名 みずほ銀行 東大阪支店
# 口座番号 1234567
# 口座名義 Teキカクセイキュウショ(カ 員 理 理 担当部
# 25
# failed to load json on sample:  202307_nttd_e377a6763f92eb351e17f1397ecf55fb.pdf-2
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 和光建設株式会社御中	請 求 書(現場別明細)	契約外・(単価契約	)
# 取引先	コード	123456
# 請求日	2013年1月30日
# ・下記の通り御請求申し上げます。
# 契約外 記入例2	2013.12.01
# 請求金額 ¥	2	7	4	000	0	円也
# 事業者登録番号
# 0000000000000000	さいたま市○○区△△町1-15-1
# ○△商事 株式会社
# 代表取締役 ○△ △雄	℡
# TEL048-000-0000
# 必ず貴社で入力
# 所
# 会社名
# 代表者
# 電	話
# 工事名称
# ○○ビル新築工事
# 登録業者は必ず入力
# 月日	品名・工種	数量	単位	単価	(税抜)	金額	(税抜)	工種細目	支払金額	(税抜)	伝 票 No,
# 31	雑金物	1.0	式	2,500,000	2,	500,000	工事	番号	2	0
# (別紙明細書の通り)	注文書	No,
# 250万の内、8%課	手動入力セル	A:	取決金額
# 税対象額が50万	B:今回迄の
# 自動入力セル	だった場合	出来高金額
# 枠内は記入しない。
# 合計金額	合計金額	額
# (税抜)	消費税額
# (法定福利費 等)	(税込)	事務処理欄	当額
# 非・不課税対象計	E:
# 値	引
# 軽減8%課税対象計	500,000	40,000	540,000	F:	立替引去
# 10%課税対象計	2,000,000	200,000	2.	200,000	G:
# 未	払 額
# 今回請求額 計	2,500,000	240,000	2,740,000	支払計	①差引計
# 科目	借方	貸方	引去処理欄(赤文字・番号↑指示)	安全協力費	無	10/10000	25/10000
# 科目
# ①取引先コード、事業者登録番号、住所氏名は貴社で記入	②請求内訳欄が不足する場合は貴社請求内訳書添付	③請求書は月末締切、翌月5日必着	は注文書No.
# ④提出は1部、貴社で控えを保管下さい。(白黒印刷)	⑤太線枠内は記入しないでください。
# は注文書o.
# 取引先名
# 消費税
# ①×%自動入力
# は注文書No.
# 取引先名
# より
# 金額
# 取引先名
# 支払
# 科目
# は注文書o.
# 取引先名
# 備考
# 経
# 理
# 管
# 理
# 担当部
# 担当者
# No.
# 金額
# ①取引先コード、住所氏名は貴社で記入②請求内訳欄が不足する場合は貴社請求内訳書添付	③請求書は月末締切、翌月5日必着	④提出は1部、貴社で控えを保管下さい⑤	枠内は記入しないでください
#
#
#  ### Json Output:
#  請求額(10%税込) 2,000,000
# 請求額(8%税込) 500,000
# 消費税額(8%) 40,000
# 消費税額(10%) 25,000
# 支払通貨 ¥
# 消費税額(10%)(支払通貨x8%税込) 25,000
# 消費税額(10%)(支払通貨x10%税込) 0
# 消費税額(10%) 140,000
# 消費税額(8%) (支払通貨x8%税込) 200,000
# 消費税額(10%)(支払通貨x10%税込) 0
# タイトル 請求書
# 26
# failed to load json on sample:  202307_nttd_e377a6763f92eb351e17f1397ecf55fb.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 和光建設株式会社御中	請 求 書(現場別明細)	契約外・(単価契約	2
# 取引先	コード	123456
# 請求日	2013年1月30日
# ・下記の通り御請求申し上げます
# 契約外 記入例1	2013.12.01
# 請求金額 ¥	1	8	5	000	円也	1
# 事業者登録番号
# 0000000000000000
# 所	さいたま市○○区△△町1-15-1
# 会社名	○△商事 株式会社
# 代表者	代表取締役 ○△ △雄	℡
# 必ず貴社で入力
# 工事名称	○○ビル新築工事
# 登録業者は必ず入力
# 電	話	TEL048-000-0000
# 月日	品名・工種	数量	単位	単価	(税抜)	金額	(税抜)	工種細目	支払金額	(税抜)	伝 票 No,
# 10	生コン	FC18-18-20N	50.0	m3	11,000	550,000	工事	番号	2	0	-
# 15	生コン	FC18-18-20N	100.0	m3	11,000	1.	100,000	注文書	No,	-
# 手動入力セル	A:	取決金額
# B:今回迄の
# 出来高金額
# 自動入力セル	枠内は記入しない。	C:
# 合計金額	合計金額	既	払 額
# (税抜)	消費税額	(税込)	事務処理欄	D:
# (法定福利費 等)	支払相当額
# 非・不課税対象計	E:
# 値	引
# 軽減8%課税対象計	F:	立替引去
# 10%課税対象計	1	650,000	165,	000	1	815,000	G:
# 未	払 額
# 今回請求額 計	1	650,000	165,	000	1	815,000	支払計	①差引計
# 引去処理欄(赤文字・番号↑指示)	安全協力費	無	10/10000	25/10000
# 科目	借方	貸方
# 科目	①取引先コード、事業者登録番号、住所氏名は貴社で記入	②請求内訳欄が不足する場合は貴社請求内訳書添付	金額	③請求書は月末締切、翌月5日必着	④提出は1部、貴社で控えを保管下さい。(白黒印刷)	科目	⑤太線枠内は記入しないでください。
# 金額
# は注文書No.
# は注文書No.
# は注文書No.
# は注文書o.
# ①取引先コード、住所氏名は貴社で記入②請求内訳欄が不足する場合は貴社請求内訳書添付	③請求書は月末締切、翌月5日必着	④提出は1部、貴社で控えを保管下さい⑤	枠内は記入しないでください
# 取引先名
# 消費税
# より	①×%自動入力
# 取引先名
# 取引先名
# 支払
# 取引先名
# 備考
# 経
# 理
# 管
# 理
# 担当者
# No.
# 担当部
#
#
#  ### Json Output:
#  請求額(165,000(税込)":165,000","請求額(1,650,000(税抜)":1,650,000","合計請求額(税抜)":1,815,000","消費税額(10%)":165,000","請求日付": "2013年1月30日","タイトル": "請求 書","支払者会社名": "和光建設株式会社","支払者住所": "所 さいたま市○○区△△町1-15-1","支払者電話番号": "TEL048-000-0000","合計請求額(税込)": "1,815,000","消費税額(8%)": "25","請求者会社名": "○△商事 株式会社","請求者住所": "××××××, ○○○○○-○○0, 東京都文京区","請求者電話番号": "××××××","合計請求額(税抜)": "1,650,000","請求年月": "2013.12.01","支払通貨": "¥","消費税額": "165,000","請求者FAX": "FX12345671","口座の種類": "現貨","口座番号": "1234555,","口座名義": "工事請求"
# 27
# failed to load json on sample:  202307_nttd_designated_billing_form.pdf-2
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 7月分請求合計表(提出用)
# 提出日令和5年7月1日
# 福美建設株式会社 御中
# 住所
# 会社名 請求元株式会社	印
# (電話番号
# 登録番号(T+13桁)	T 1234567890123
# 振込銀行	みずほ 銀行	東大阪 支店
# 預金種目	普通預金	口座No.1234567
# 支払期限	2023/7/31
# 口座名義	コーザメイギ
# No.	工事名称	請求金額(税込)	備	考
# ST工事	285,800
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 合	計	285,800
# 2023.01様式
#
#
#  ### Json Output:
#  請求額(税込) : 285,800(税込)
# 請求日付 : 令和5年7月1日
# 請求者会社名 : 請求元株式会社
# 銀行名 : みずほ銀行
# 銀行支店名 : 東大阪支店
# 口座の種類 : 普通預金
# 口座番号 : 1234567
# 口座名義 : コーザメイギ
# 支払期日 : 2023/7/31
# タイトル : 7月分請求合計表(提出用)
# 28
# failed to load json on sample:  202307_nttd_designated_billing_form.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 7月分請求合計表(業者控)
# 提出日 令和 5年7月1日
# 福美建設株式会社 御中
# 住所
# 会社名	請求元株式会社	印
# (電話番号
# 登録番号(T+13桁)	T 1234567890123
# 振込銀行	みずほ 銀行	東大阪	支店
# 預金種目	普通預金	口座No.	1234567
# 支払期限	2023/7/31
# 口座名義	コーザメイキ
# No.	工事名称	請求金額(税込)	備 考
# ST工事	285,800
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 合	計	285,800
# <お願い>提出される請求書ごとの工事名(品目等)及び金額を
# 提出してください。
# 〒399-4231
# 長野県駒ヶ根市中沢4894-1	福美建設 株式会社	管理本部
# TEL 0265-87-2211	FAX 0265-87-2057
# 2023.01様式
#
#
#  ### Json Output:
#  請求額(10%税込) 275,800
# 請求額(8%税込) 10,000
# 登録番号(T 1234567890123) T 1234567
# 29
# failed to load json on sample:  202307_nttd_cosmo_bill_2023_06.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書(10月分)
# (様式B)
# コスモ建設株式会社	御中
# (請求者)	西暦
# 取引先コード番号
# 2023年
# 10
# 月
# 20
# 123456
# 振込先	銀行名	みずほ銀行	支店名	東大阪支店
# フリガナ	テキカクセイキュウショ(カ
# 口座名	適格請求書株式会社
# フリガナ
# 業者名
# 電話番号
# 登録番号
# セイキュウモトカブシキガイシャ
# 請求元株式会社
# ⑪
# 預金種類	普通	(口座番号)	1234567
# 支払期限	2023/10/31
# 下記の通り請求致します。
# T 5120001091187
# 請求金額	¥
# 454,192
# -	(税込)
# 支払金額	¥
# (税込)
# (内_訳)	10%対象	(税抜)
# 8%対象	(税抜)
# 非課税
# 406,000
# 消費税
# 消費税
# 40,600
# 予算費目
# 金額
# 2,400
# 192
# 5,000
# 工事番号
# 123456
# 000
# 件名
# (仮称)○△○○新築工事
# 月日
# 品名・規格・寸法
# 数量
# 単位
# 単価
# 金額
# 備考
# 10/10
# 壁・柱 クロス貼替
# 160.00
# 800
# 128,000
# タイルカーペット張替
# 115.00
# 2111
#
# 253,000
# 10/20
# ソフト巾木貼替
# 60.00
# 本
# 300
# 18,000
# 残材処分
# 1.00
# 7,000
# 7,000
# 飲料水
# 24.00
# 本
# 100
# 2,400
# 印紙代
# 1.00
# 式
# 5,000
# 5,000
# 工
# 事
# 費
# 計
# 413,400
#
#
#  ### Json Output:
#  請求額(8%税込) :50000000000000(税込)
# 請求額(10%税込) :40600000000000(税抜)
# 消費税額(10%) :40,600
# 消費税額(8%) :0(消費税額(8%))
# 銀行支店名 :東大阪支店
# 銀行名 :みずほ銀行
# 口座の種類 :普通
# 口座番号 :1234567
# 口座名義 :適格請求書株式会社
# 請求者会社名 :請求元株式会社
# タイトル :請求書(10月分)
# 支払者会社名 :コスモ建設株式会社
# 支払期日 :2023/10/31
# 請求年月 :10月20123年12月123456
# 請求者電話番号 :○○○1234
# 登録番号 :SE12345671234567
# 請求額(税込) :454,192
# 消費税額 :40,600(消費税額(8%))
# 請求者住所 :〒○○○-○○○ 様式B, 銀座, 東京, 東京府
# 30
# failed to load json on sample:  202307_nttd_bill_outsourcing_20230601.pdf-2
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 枚中のP
# ※カブキコードを記入	→	1312345-000
# フリガナ	カブ	キケンセツ(カ
# 〒	171-8561
# 住所・社名・氏名	東京都豊島区高田3-31-5
# 株木建設株式会	社
# 取締役社長	株木康吉	⑲
# TEL	03	3984	4111
# FAX	03	3984	6900
# 建設業許可番号	特3-第3号
# 契約金額	適格請求書発行事業者登録番号
# 5,500,000	T7-1234-5678-9012
# 約残金	工事完成検査日	年	月	日
# ,000,000	引渡日	年	月	目
# 400,000	株木建設	⑭
# ,400,000	確認者
# 協力会社
# ※累計請求額が100%となった際には上記記載のこと
# 振込先	常陽銀行	本店営業部
# 銀行コード	3	支店コード
# 種別・番号	当座預金	123
# 口座名義	カ	ブキケ	ン	セ	ツ	(カ
# (カタカナ)
# 2023.06.01改訂
#
#
#  ### Json Output:
#  請求額(5,500,000(税込)": "5,500,000(8%税込)",
# "請求額(100,000(税込)": "100,000(8%税込)",
# "口座名義": "カブキケンセツ(カ",
# "登録番号": "T7-1234-5678-9012",
# "口座番号": "123",
# "銀行名": "常陽銀行",
# "銀行支店名": "本店営業部",
# "支払期日": "引渡日 年月日",
# "タイトル": "請求書",
# "請求者会社名": "株木建設株式会社",
# "請求者住所": "東京都豊島区高田3-31-5",
# "請求者電話番号": "0339844111",
# "請求者FAX": "0339846900",
# "支払者会社名": "確認者",
# "合計請求額(税込)": "100,000(8%税込)",
# "支払通貨": "¥",
# "合計請求額(税抜)": "5,500,000(8%税抜)",
# "請求年月": "5年6月",
# "請求日付": "2023.06.01",
# "請求額(100,000(税抜)": "100,000(8%税抜)",
# "請求者口座の種類": "当座預金",
# "登録番号の支払者会社": "常陽銀行",
# "口座名義の誤植": "カブキケンセツ(カ"
# 31
# failed to load json on sample:  202307_nttd_bill_outsourcing_20230601.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 外注契約用
# 請求書(請求元控
# 株木建設株式会社	御中	茨城本店
# 工事番号 BC2-	K3186001	-	01
# 請求年月日	BC1-	2023年6月20日
# 工事名称	○○駅前改良工事
# 利用月:2023年6月分	支払期限:2023年6月31日
# 注文番号	BC3-	001	01	工事内容	土工事
# 当初契約額	変更増減額	計	消費税額	10	%	税込彦
# 5,000,000	0	5,000,000	500,000
# 区	分	前回	迄	今回計上額	今回迄累計	契約
# 請求金額	0	1,000,000	1,000,000	4
# 消費税額	10	%	100,000	100,000
# 税込請求額	4	1,100,000	1,100,000	4
# 入力上の注意事項
# 1	この請求書は3枚1組になっていますので、必要事項(水色の箇所)を入力後印刷し、
# " 請求元控"を除いた" 現場控・本支店用"に捺印の上、担当作業所に提出してください。
# 	注文番号欄には株木建設株式会社発行の注文書記載の"3桁"の注文番号を入力してください。
# 初めてこの請求書を使用される方および従来の住所、TEL、FAX、取引銀行等の変更をされる方は、
# あらかじめ株木建設株式会社指定様式の「取引先登録カード」を提出してください。
#
# 本請求に依る債権は、株木建設株式会社の書面による承諾なしに第三者へ譲渡しません。
# 事務取扱手数料は請求元で負担します。
#
#
#  ### Json Output:
#  請求額(4%税込) 1,100,000
# 消費税額 100,000
# 合計請求額(税込) 1,100,000
# 支払通貨:円支払期日:2023年6月31日口座名義(登録番号):T1222141413121[登録番号]タイトル:請求請求者電話番号:XXXXXXX FAX:XXXXXXX
# 32
# failed to load json on sample:  202307_nttd_202307030848326140.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書(10月分)
# 北国リース株式会社	金沢営業所 御中
# 下記の通り請求致します。
# 令和5年10月1日
# 住所	924-0854	石川県白山市出合島町616番地
# 氏名	請求元株式会社
# TEL	076-277-2201
# 登録番号 T1234567890123
# 振込先	北國 銀行	中央 支店
# 0012345	名義人	適格請求書株式会社
# 普通預金	口座番号	カ
# ナ	テキカクセイキュウショ(カ
# 5,000,000	税抜額
# 消費税	500,000
# 合計金額	¥5,500,000
# ※請求書は毎月20日締とし25日までに、各営業所に提出して下さい。
# 支払期限:2023/10/31
# 日付	摘要(品名)	数量	単位	単価	金額
# 9月30日	テスト品名	式	5,000,000
# 合計	5,000,000
# 税抜額
# 消費税
# 合計
# 10%対象
# 5,000,000
# 500,000
# 5,500,000
# 8%対象
# 合計
# 5,000,000
# 500,000
# 5,500,000
# 1枚中	1枚
# 北国A4横1511002
#
#
#  ### Json Output:
#  請求額(8%税込):5,000,000
# 請求額(10%税込):5,000,000
# 消費税額(10%):500,000
# 消費税額(8%):500,000
# 合計請求額(税込):5,500,000
# 口座の種類 G 普通預金
# 33
# failed to load json on sample:  202307_nttd_20230516103602659.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 総 括 請 求 書(7月分)
# 中央電設工事株式会社 御中
# 令和 5 年 7月末日締め
# 請求金額	¥10,000-	(税別)
# 消費税額	%)	¥-
# 消費税額	10	%)	¥1,000-
# 請求合計金額	¥11,000-	(税込)
# 住所
# 会社名	請求元株式会社	⑪
# 代表者	登録番号	T1223334444555
# 振込先
# 銀行名	みずほ銀行	支店名	東大阪支店
# 預金種別	普通	口座番号	1234567
# フリガナ	テキカクセイキュウショ(カ
# 口座名義	適格請求書株式会社
# 支払期限:2024/1/15
# No	工事番号	工事名	請求金額(税別)	担当	備考
# 工事1	工事名1	10,000
# 合 計(税込)	¥11,000
# 税率別内訳 税抜金額
# 軽減8%対象	¥0
# 10%対象	¥10,000
#
#
#  ### Json Output:
#  請求額(8%税込):10,000
# 請求額(10%税込):1,000
# 合計請求額(税込):11,000
# 支払者名:中央電設工事株式会社
# 34
# failed to load json on sample:  202307_nttd_202209seikyusyo.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書	(7月分)
# 西暦	2023年7月7日
# 工事名
# 請求金額	¥1,100
# 上記のとおり請求いたします。
# 株式会社安部日鋼工業御中
# 発行事業者登録番号	T1223334444555
# (署名又は署名判)
# 請求元株式会社
# 摘 要	契約金額	又は単価	出来高又は	納入数量	金 額
# 小麦粉	1,000	1,000
# 小	計	1,000
# 消 費	税	8%
# 消 費 税	10%	100
# 合	計	1,100
# 注文書	No.	契約金額	既受領額
# 変更増減額	今回請求額
# 請求第	計	差引残高
# 請郵住氏	者号所名号
# 支払期限:2023/7/31
# 振込先	金融機関名	支店名	口座種別	口座番号
# みずほ銀行	東大阪	1-普通	1234567
# フリガナ	テキカクセイキュウショ(カ
# 口座名義	適格請求書株式会社
# 貴社控
# 税率別内訳 税抜金額
# 10%対象	¥1,000
# 軽減8%対象	¥0
#
#
#  ### Json Output:
#  請求額(8%税込) 1,000
# 請求額(10%税込) 1,000
# 口座名義 適格請求書株式会社
# 登録番号 T1223334444555
# 請求日付 2023年7月7日
# 請求者会社名 株式会社安部日鋼工業
# 請求者住所 浜松市中央区西町1212
# 請求者電話番号 050-5511-1212
# 支払者会社名 工事名不明
# 口座の種類 G 普通
# 口座番号 1234567
# 口座名義支払者の会社名 FIRE 工事株式会社
# 銀行名行銀行支店名東大阪支店
# 消費税額(8%) 800
# 消費税額(10%) --
# 合計請求額 1,100
# 支払期日 2023/7/31
# 登録番号 T1223334444555
# 35
# failed to load json on sample:  202307_nttd_005.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書
# 請求先株式会社 御中
# 下記の通りご請求申し上げます。
# 請求日:2023/7/7
# 利用月:7月
# 登録番号:T1223334444555
# 請求元株式会社
# 件名
# お支払い期限	2023/7/31
# 振込先	みずほ銀行 東大阪支店 普通 1234567 テキカクセイキュウショ(カ
# ※お振込み手数料は御社ご負担にてお願いいたします。
# 繰越金額:	¥0
# ご請求金額(税込)	¥550
# 日付	品番・品名	数量	単位	単価	税率	金額	摘要
# 2023/7/7	小麦粉	個	¥500	10%	¥500
# 小計	¥500
# 税率内訳	税抜金額	消費税額	消費税	¥50
# 10%対象	¥500	¥50	合計金額	¥550
# 軽減8%対象	¥0	¥0
# 非課税	¥0	¥0
#
#
#  ### Json Output:
#  請求額(8%税込) - 請求額(10%税込) - 消費税額(10%) - 消費税額(8%) - 合計請求額 -支払通貨 -支払者会社名 -支払期日 -口座番号 -口座の種類 -銀行支店名 -タイトル -請求日付 -請求者会社名(5年毎請求者会社名登録番号) -合計請求額(税込) -支払者名(カメラ請求者会社名):銀行口座の種類が請求額(10%税込)か請求額(8%税込)かをご考査ください。口座の種類が請求額(10%税込)か請求額(8%税込)かの登録番号(T1223334444555)
# 36
# failed to load json on sample:  202307_nttd_004.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 飛島建設株式会社
# 発行日:2023年7月7日
# 中央	支店
# 請	求 書 [7月分
# 作業所
# 御中	部・課
# 発行事業者登録番号	T1223334444555
# 住所
# 社名	請求元株式会社	印
# 取引先コード
# 請求番号
# 請求年月日
# 番	月
# 請求金額
# 1080円
# 下欄は契約分だけ御記入下さい。	契約金額	契約増減額
# 契約金額計
# 前回迄の請求額	今回の請求額
# 請求金額計
# 契約残高
# 注文番号
# 摘要(品名)	数量	単位	単価	金 額	備 考
# 小麦粉	1,000	1,000
# 計	1,080
# 記入上のお願い
# 取引先コード欄には、取引先登録票で通知したコードを正確に捺印または記入して下さい。
# 2.請求番号欄には、任意の4桁の数字を記入し、
# 注文書が異なる場合には請求書を別々に作成し	て下さい。
# 4.	請求書の提出先は、物品サービス等の納入部署	にして下さい。
# 請求書内容がひとつの請求書に書ききれない場	請求書内容がひとつの請求書に書ざされない場合には、複数の請求書にまたがって内訳を記入
# (この請求書は3部1組で作成し、控えを除いた2部を飛島建設(株)に提出して下さい。)
# 税率別内訳 税抜金額 消費税合計額
# 10%対象
# 軽減8%対象	¥1,000	¥80
# 銀行名	みずほ銀行(0001)
# 振込先	科目	普通	支店名
# テキカクショ(カ	口座番号	東大阪支店(484)
# 口座名義	1234567
# 支払期限:2024/1/15
# Ver.1.1
#
#
#  ### Json Output:
#  請求額(8%税込) 1,000
# 消費税額(10%) 80
# 消費税額(8%) - -
# 37
# failed to load json on sample:  202307_nttd_003.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 御請求書
# 請求番号:	0000000001
# 請求日:2021年12月20日
# 請求先株式会社	御中
# 株式会社請求元登録
# 番号:T456456465467
# 〒
# 住所:
# TEL:
# FAX:
# MAIL:
# 担当者
# 令和5年6月分
# 件名:
# 合計金額	¥¥15,000,000-(税込)
# NO	項目名	軽減税率	数量	単位	単価	金額
# 株式会社あああ	11	3123	1111
# あったか	12313	222
# 10%対象計	1111
# 8%対象計	2222
# 小計(税抜)	33
# 消費税(10%)	444
# 消費税(8%)	555
# 備考:
# お支払い:2024/1/1まで
# 第1振込先
# 銀行名	みずほ銀行	支店名	東京
# 振込先	科目	普通	口座番号	1234567
# 口座名義	カ)セイキュウモト
#
#
#  ### Json Output:
#  消費税額(10%) :444
# 消費税額(8%) :555
# 口座の種類 :普通
# 口座番号 :1234567
# 口座名義 :カ)セイキュウモト
# タイトル :御請求書
# 38
# failed to load json on sample:  202307_nttd_002.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# (様式B)	令和 3年	6月23日
# 請求書
# 株式会社大槻工務店	御中	令和3年8月分
# (請求者)
# 適格請求書発行事業者登録番号
# 〒
# 住所
# 電話番号	fax
# フリガナ	テキカクセイキュウショカブシキガイシャ	村
# 会社名	適格請求書株式会社	田
# 振込先銀行名	みずほ銀行(0001)
# 支店名	東大阪支店(484)
# フリガナ	テキカクセイキュウショ(カ
# 口座名	適格請求書株式会社
# 預金種類	当座	口座番号	1234567	普通
# 支払期限	2023/7/31
# T	1234567890123
# 合計請求金額	¥11,000
# 下記の通り請求致します。
# 工事担当者	田中工事
# No.	月日	工事件名	品名・規格・寸法	数量	単位	単価	金額
# 6/23	工事1	品名1	式	10,000	10,000
# 小計	10,000
# 消費税	10	%	1,000
# 8	%
# 合計	¥11,000
# 【請求書作成、提出の際の注意事項】
# ①請求書は当社指定請求書を使用し、本社まで郵送願います。
# ②この請求書は、工事担当者ごと(太枠内記入)での提出をお願い致します。
# ③毎月20日締、25日必着、翌25日支払(26日が休日の場合は翌日)
# ④請求書必着日を過ぎると翌月扱いになりますのでご注意ください。
# ⑤その他記入、提出等ご不明点ございましたら担当者又は本社までお願いいたします。
# 株式会社大槻工務店
#
#
#  ### Json Output:
#  請求額(8%税込) 1,000
# 請求額(10%税込) 10,000
# 合計請求額(税込) 11,000
# 消費税額(10%) 1,000
# 消費税額(8%) -
# 39
# failed to load json on sample:  202307_nttd_001.pdf-1
# 以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧
# 請求書番号
# 請求書	(6月分)	2023年6月1日
# 1i	23122
# (請求先)
# 株式会社請求先
# 住所 東京都港区1-1
# (法人名)株式会社請求元
# 氏 名
# (肩書・代表者氏名)	請求元 太郎
# 次のとおり請求します、支払期限:2023/6/23	発行者登録番号	T1231231231235
# 請求金額
# 印
# 3	1	4	1	2	4-1	1
# 件 名てすと
# 業務内容	履行月	数量	単位	単価	金額(円)
# 業務1	2023/6	213	222
# 業務②*	2023/6	123	123,123
# 業務4	2023/6	1,231	221,313
# 合計	31,412,411
# 消費税10%対象計	消費税8%対象計	¥123,321	¥1,231	内消費税	内消費税	¥1,234	¥1,241
# 振込先
# 金融機関名	三井住友銀行	支店名	テスト支店
# 預金種目	普通	口座番号
# 口座名義	(カタカ	ナ)	フリコミサキ ダロウ
#
#
#  ### Json Output:
#  請求日付: 2023年6月1日
# タイトル:請求書
# 請求者の会社名:株式会社請求元
# 支払者の会社名:株式会社請求先
# 支払期日:2023/6/23
# 請求額(8%税込):1,231
# 請求額(10%税込):31,412,411
# 登録番号:T1231231231235
# 口座の種類:普通
# 口座番号:1234123
# 口座名義:フリコミサキ ダロウ
# 請求年月:6月分
# 請求番号:2023122131412411
# 支払通貨:円
# Average prediction time:  6.844749450683594
# Variance of prediction time:  0.0

# %%
model, tokenizer, dataset_config = model, tokenizer, receipt_dataset
df_columns = ["file_name", "key", "gt", "prediction", "correct"]
eval_df = pd.DataFrame(columns=df_columns)
dataset = get_preprocessed_dataset(tokenizer, dataset_config, 'val')
model.eval()
print("inside evaluate")
print("dataset length: ", len(dataset))
# Out:
# running on partition val; there are 40 samples
# inside evaluate
# dataset length:  40

# %%
i = 0 
print(i)
sample_df = pd.DataFrame(columns=df_columns)
ann = dataset.ann[i]
correct = ann["output"]
name = ann["fn"]

sample_df["file_name"] = name
eval_prompt = format.format_map(ann)
# Out:
# 0

# %%
model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
model.eval()
with torch.no_grad():
    # measure how long prediction is taking
    start = time.time()
    out = tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True)
    end = time.time()

model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")

# %%
out
# Out:
# '以下のテキスト一覧は、pdfの請求書ドキュメントからOCRをした結果を左上から順番に並べたものです。テキストから次の項目一覧の値をJson形式で出力してください。存在しない項目に関しては出力しないでください。### テキスト一覧\n〒\t650-0031\n兵庫県神戸市中央区東町○○○-〇\n請求先株式会社\t御中\n御請求書\n請求番号:\t0000000001\n請求日:\t2021年12月20日\n利用月:\t株式会社請求元\t2021年12月分\n登録番号: T1223334444555\n件名:テスト請求書\nTEL\nFAX\nMail\n担当者\n合計金額\t¥1,000-\t(税込)\n日付\t項目名\t数量\t単価\t税率\t金額\n12月10日\t小麦粉\t1,000\t8%\t1,000\n小計\t¥1,000\n消費税(8%)\t¥80\n消費税(10%)\t¥0\n合計\t¥1,000\n税率別内訳 税抜金額\n10%対象\t¥0\n軽減8%対象\t¥1,000\n備考:\nお支払い条件:\n第1振込先\n振込先\t銀行名\tみずほ銀行(0001)\t支店名\t東大阪支店\t(484)\n科目\t普通\t口座番号\t1234567\n口座名義\tテキカクショ(カ\n第2振込先\n振込先\t銀行名\t支店名\n科目\t口座番号\n口座名義\n支払期限:2024/1/15\n\n\n ### Json Output: \n 登録番号 T1223334444555\n請求額(8%税込) 1,000\n請求額(10%税込) 0\nタイトル請求書[登録番号 T1223334444555]\n請求番号 0000000001\n請求日付 2021年12月20日\n請求者会社名:株式会社請求元\n請求者住所:〒650-0031 兵庫県神戸市中央区東町○○○-〇\n請求者電話番号:XXXX-XXXX-XXXX\n支払者会社名:請求先株式会社\n請求年月:2021年12月分\n合計請求額(税込) 1,000\n支払通貨:¥\n消費税額(10%) 0\n消費税額(8%) 80\n合計請求額(税抜) 1,000\n消費税額(10%) 0\n消費税額(8%) 1,000\n支払期日 2024/1/15\n口座の種類支払者名義カカ(カ\n口座番号 1234567\n銀行名支店名 東大阪支店(みずほ銀行(0001)\n登録番号 T1223334444555(税関)\n請求額(10%税込) 0(税関)\n請求額(8%税込) 1,000(税関)\n消費税額(10%) 0(税関)\n消費税額(8%) 1,000(税関)\n'

# %%
    for i in range(len(dataset)):
        print(i)
        sample_df = pd.DataFrame(columns=df_columns)
        ann = dataset.ann[i]
        correct = ann["output"]
        name = ann["fn"]

        sample_df["file_name"] = name
        eval_prompt = format.format_map(ann)
        
        # store all prediction time
        time_list = []
        with torch.no_grad():
            model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
            # measure how long prediction is taking
            start = time.time()
            out = tokenizer.decode(model.generate(**model_input, max_new_tokens=1000)[0], skip_special_tokens=True)
            end = time.time()
            time_list.append(end - start)

            # read output as json
            try:
                json_output = json.loads(out)
                json_correct = json.load(correct)
            except:
                print("failed to load json on sample: ", name)
                print(out)
                json_output = None
                json_correct = None

            if json_output is not None:
                for key in json_output:
                    sample_df["key"] = key
                    sample_df["gt"] = json_correct.get(key, None)
                    sample_df["prediction"] = json_output[key]
                    sample_df["correct"] = json_output[key] == json_correct.get(key, None)
                    eval_df = eval_df.append(sample_df, ignore_index=True)

    print("Average prediction time: ", sum(time_list)/len(time_list))
    print("Variance of prediction time: ", sum([(x - sum(time_list)/len(time_list))**2 for x in time_list])/len(time_list))

    return eval_df
